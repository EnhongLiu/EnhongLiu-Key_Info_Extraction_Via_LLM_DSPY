# %%
from datasets import Dataset, DatasetDict
from setfit import SetFitModel, Trainer, TrainingArguments, sample_dataset
import pickle 
import pandas as pd

# %%
# df.sample(300, random_state=7).to_excel('set-fit-data.xlsx')

# %%
df = pd.read_excel(r"C:\Users\jvhua\OneDrive\Desktop\ISYE-CSE-MGT-6748-Group-1\set-fit-data.xlsx")

# %%
df = df[['uuid', 'string_chunk', 'label']].rename(columns = {'string_chunk': 'text'})

# %%
dataset = Dataset.from_pandas(df)

# %%
train_val_test_split = dataset.train_test_split(test_size=0.5)

train_val_split = train_val_test_split['train'].train_test_split(test_size=0.8)

# %%
dataset_dict = DatasetDict({
    'train': train_val_split['train'],
    'validation': train_val_split['test'],
    'test': train_val_test_split['test']
})

# %%
dataset_dict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['uuid', 'text', 'label'],
#         num_rows: 30
#     })
#     validation: Dataset({
#         features: ['uuid', 'text', 'label'],
#         num_rows: 120
#     })
#     test: Dataset({
#         features: ['uuid', 'text', 'label'],
#         num_rows: 150
#     })
# })

# %%
# Simulate the few-shot regime by sampling 8 examples per class
train_dataset = sample_dataset(dataset_dict["train"], label_column="label", num_samples=8)
eval_dataset = dataset_dict["validation"].select(range(100))
test_dataset = dataset_dict["test"].select(range(100,))
# Out:
# c:\Users\jvhua\miniconda3\envs\langchain\Lib\site-packages\setfit\data.py:154: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.apply(lambda x: x.sample(min(num_samples, len(x)), random_state=seed))

# %%
# Load a SetFit model from Hub
model = SetFitModel.from_pretrained(
    "sentence-transformers/paraphrase-mpnet-base-v2",
    labels=[0, 1],
)
# Out:
# c:\Users\jvhua\miniconda3\envs\langchain\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.

# %%
args = TrainingArguments(
    batch_size=8,
    num_epochs=10,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    max_seq_length = 512,
    load_best_model_at_end=True,
)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    metric="accuracy",
    column_mapping={"text": "text", "label": "label"}
)
# Out:
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# Map:   0%|          | 0/16 [00:00<?, ? examples/s]

# %%
# Train and evaluate
trainer.train()
metrics = trainer.evaluate(test_dataset)
print(metrics)
# Out:
# ***** Running training *****
#   Num unique pairs = 144
#   Batch size = 8
#   Num epochs = 10
#   Total optimization steps = 180
#   0%|          | 0/180 [00:00<?, ?it/s]
#   0%|          | 0/180 [00:00<?, ?it/s]
# {'embedding_loss': 0.1983, 'learning_rate': 1.111111111111111e-06, 'epoch': 0.06}
#   0%|          | 0/668 [00:00<?, ?it/s]
# {'eval_embedding_loss': 0.2467, 'learning_rate': 2e-05, 'epoch': 1.0}
#   0%|          | 0/668 [00:00<?, ?it/s]
# {'eval_embedding_loss': 0.227, 'learning_rate': 1.7777777777777777e-05, 'epoch': 2.0}
# {'embedding_loss': 0.0021, 'learning_rate': 1.6049382716049385e-05, 'epoch': 2.78}
#   0%|          | 0/668 [00:00<?, ?it/s]
# {'eval_embedding_loss': 0.2256, 'learning_rate': 1.555555555555556e-05, 'epoch': 3.0}
#   0%|          | 0/668 [00:00<?, ?it/s]
# {'eval_embedding_loss': 0.2304, 'learning_rate': 1.3333333333333333e-05, 'epoch': 4.0}
#   0%|          | 0/668 [00:00<?, ?it/s]
# {'eval_embedding_loss': 0.2326, 'learning_rate': 1.1111111111111113e-05, 'epoch': 5.0}
# {'embedding_loss': 0.0004, 'learning_rate': 9.876543209876543e-06, 'epoch': 5.56}
#   0%|          | 0/668 [00:00<?, ?it/s]
# {'eval_embedding_loss': 0.2349, 'learning_rate': 8.888888888888888e-06, 'epoch': 6.0}
#   0%|          | 0/668 [00:00<?, ?it/s]
# {'eval_embedding_loss': 0.235, 'learning_rate': 6.666666666666667e-06, 'epoch': 7.0}
#   0%|          | 0/668 [00:00<?, ?it/s]
# {'eval_embedding_loss': 0.2372, 'learning_rate': 4.444444444444444e-06, 'epoch': 8.0}
# {'embedding_loss': 0.0003, 'learning_rate': 3.7037037037037037e-06, 'epoch': 8.33}
#   0%|          | 0/668 [00:00<?, ?it/s]
# {'eval_embedding_loss': 0.2345, 'learning_rate': 2.222222222222222e-06, 'epoch': 9.0}
#   0%|          | 0/668 [00:00<?, ?it/s]
# {'eval_embedding_loss': 0.2355, 'learning_rate': 0.0, 'epoch': 10.0}
# Loading best SentenceTransformer model from step 54.
# {'train_runtime': 1403.1921, 'train_samples_per_second': 1.026, 'train_steps_per_second': 0.128, 'epoch': 10.0}
# Applying column mapping to the evaluation dataset
# ***** Running evaluation *****
# {'accuracy': 0.85}

# %%
save_directory = r"C:\Users\jvhua\OneDrive\Desktop\ISYE-CSE-MGT-6748-Group-1\setfit_model"
trainer.model._save_pretrained(save_directory=save_directory)
